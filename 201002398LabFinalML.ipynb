# %% [markdown]
# <a href="https://colab.research.google.com/github/na0260/machine-learning-lab/blob/main/201002398LabFinalML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/snails_gc.csv')
df.head()
# Out:
#   sex  length  diameter  height  whole_weight  shucked_weight  viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   F   0.530     0.415   0.150        0.7775          0.2370          0.1415
#
#    shell_weight  rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.330     20

# %%
df['sex'] = df['sex'].map({'M': 0, 'F': 1})
df.head()
# Out:
#    sex  length  diameter  height  whole_weight  shucked_weight  \
# 0    0   0.455     0.365   0.095        0.5140          0.2245
# 1    0   0.350     0.265   0.090        0.2255          0.0995
# 2    1   0.530     0.420   0.135        0.6770          0.2565
# 3    0   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.530     0.415   0.150        0.7775          0.2370
#
#    viscera_weight  shell_weight  rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.1415         0.330     20

# %%
from sklearn.model_selection import train_test_split

X = df.iloc[:, 1:]
y = df['sex']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=62)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.6091549295774648

# %%
results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(results)
# Out:
#       Actual  Predicted
# 2340       1          0
# 837        0          0
# 701        1          0
# 1724       0          0
# 59         1          0
# ...      ...        ...
# 1728       0          1
# 2829       0          0
# 2479       0          0
# 935        0          0
# 46         0          0
#
# [284 rows x 2 columns]
